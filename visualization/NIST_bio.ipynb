# %%
from Bio import SeqIO
import matplotlib.pyplot as plt
import os

# Single_Source/Applied_Biosystems_GlobalFiler/GF_2800M.hid
# Single_Source/Promega_Powerplex_Fusion_6C/PPF6C_NTD01.hid

file_name = 'Single_Source/Promega_Powerplex_Fusion_6C/PPF6C_NTD01.hid'
record = SeqIO.read(file_name, "abi")

file_size = os.path.getsize(file_name)
print(f"File size: {file_size} bytes")
# Out:
# File size: 804689 bytes

# %%
list(record.annotations.keys())
# Out:
# ['sample_well',
#  'dye',
#  'polymer',
#  'machine_model',
#  'run_start',
#  'run_finish',
#  'abif_raw',
#  'molecule_type']

# %%
for key in record.annotations.keys():
    print(key, ":", record.annotations[key])
# Out:
# sample_well : b'G07'
# dye : None
# polymer : b'POP4'
# machine_model : None
# run_start : 2017-05-30 09:27:19
# run_finish : 2017-05-30 10:04:39
# abif_raw : {'AAct1': False, 'ABED1': b'2017-12-02 23:59:00.0', 'ABID1': b'2017-05-23 09:27:00.0', 'ABLt1': b'1702373', 'ABRn1': 3, 'ABTp1': b'ABC', 'APXV1': b'1', 'APrN1': b'WEN ILS 500', 'APrV1': b'SizeCaller v1.1.0', 'APrX1': b'<?xml version="1.0" encoding="UTF-8"?> <qc-protocol name="WEN ILS 500" version="SizeCaller v1.1.0" userName="" comments="" created="1448924566419" createUserName="" modified="1448924566409" modifyUserName="" uuid="71ca151e-5199-475c-a0dc-8e2c7507e207" securityID="" immutable="false" systemOwned="false" locked="false" unlockable="true" validated="false" checksum="0xD49034D8F19CECC411FEE9580240B25F" rgb="0;0;0" auditActive="0" iconFile=""><qcParameter><analysisSettings><parameterMap><parameter name="AnalysisDyes">1,2,3,4,5,6</parameter><parameter name="AnalysisMode">1</parameter><parameter name="AnalysisStopPoint">1000000</parameter><parameter name="PeakDetectorTauB">key=1,value=0.0;key=2,value=0.0;key=3,value=0.0;key=4,value=0.0;key=5,value=0.0;key=6,value=0.0;</parameter><parameter name="PeakDetectorDegree">key=1,value=3;key=2,value=3;key=3,value=3;key=4,value=3;key=5,value=3;key=6,value=3;</parameter><parameter name="AnalysisAllDyes">true</parameter><parameter name="BaseliningWindowSize">key=1,value=51;key=2,value=51;key=3,value=51;key=4,value=51;key=5,value=51;key=6,value=51;</parameter><parameter name="SizingQualityCheckingRangeStart">0.0</parameter><parameter name="AnalysisFullRange">true</parameter><parameter name="PeakDetectorMinWidth">key=1,value=2;key=2,value=2;key=3,value=2;key=4,value=2;key=5,value=2;key=6,value=2;</parameter><parameter name="PrimerPeakPresent">true</parameter><parameter name="SizingFullRange">false</parameter><parameter name="SizingStopSize">500.0</parameter><parameter name="SmoothingValue">key=1,value=2;key=2,value=2;key=3,value=2;key=4,value=2;key=5,value=2;key=6,value=2;</parameter><parameter name="SizingQualityCheckingRangeStop">800.0</parameter><parameter name="SizingStartSize">60.0</parameter><parameter name="SmoothingNeeded">key=1,value=true;key=2,value=true;key=3,value=true;key=4,value=true;key=5,value=true;key=6,value=true;</parameter><parameter name="PeakDetectorWindow">key=1,value=15;key=2,value=15;key=3,value=15;key=4,value=15;key=5,value=15;key=6,value=15;</parameter><parameter name="AnalysisStartPoint">0</parameter><parameter name="PeakDetectorTauE">key=1,value=0.0;key=2,value=0.0;key=3,value=0.0;key=4,value=0.0;key=5,value=0.0;key=6,value=0.0;</parameter><parameter name="BaseliningNeeded">key=1,value=true;key=2,value=true;key=3,value=true;key=4,value=true;key=5,value=true;key=6,value=true;</parameter><parameter name="SizingQualityCheckingNeeded">true</parameter><parameter name="SizeCallerName">LocalSouthern</parameter><parameter name="PeakDetectorMinHeight">key=1,value=175;key=2,value=175;key=3,value=175;key=4,value=175;key=5,value=175;key=6,value=175;</parameter></parameterMap></analysisSettings><size-standard parserID="com.apldbio.ce.pa.fragment.da.SizeStandardDAO"><sizeStandard name="WEN ILS 500" version="v1.0.0" userName="" comments="" created="1448924489679" createUserName="" modified="1448924489679" modifyUserName="" uuid="e69975b7-b2fb-4f3d-b686-75461436bd46" securityID="" immutable="false" systemOwned="false" locked="false" unlockable="true" validated="false" checksum="0x3F07A216B6EB7989058E736EBAF84FFC" rgb="0;0;0" auditActive="0" iconFile=""><dyeIndex>5</dyeIndex><sizes>60.0,65.0,80.0,100.0,120.0,140.0,160.0,180.0,200.0,225.0,250.0,275.0,300.0,325.0,350.0,375.0,400.0,425.0,450.0,475.0,500.0</sizes><normalization></normalization></sizeStandard></size-standard></qcParameter><qcFlagSetting><flagSettings><settingMap><setting name="SizingQualityThresholds">0.75,0.25</setting><setting name="SpectralPullupScan">1</setting><setting name="BroadPeakAffectingSizingQualityWeight">0.5</setting><setting name="SpectralPullupRatio">0.1</setting><setting name="BroadPeakThreshold">1.5</setting></settingMap></flagSettings></qcFlagSetting></qc-protocol>', 'AVld1': b'fa ...
# molecule_type : DNA

# %%
raw_data = record.annotations["abif_raw"]
list(raw_data.keys())
# Out:
# ['AAct1',
#  'ABED1',
#  'ABID1',
#  'ABLt1',
#  'ABRn1',
#  'ABTp1',
#  'APXV1',
#  'APrN1',
#  'APrV1',
#  'APrX1',
#  'AVld1',
#  'AmbT1',
#  'Anld1',
#  'AsyC1',
#  'AsyN1',
#  'AsyV1',
#  'CAED1',
#  'CAID1',
#  'CALt1',
#  'CARn1',
#  'CASN1',
#  'CBED1',
#  'CBID1',
#  'CBLt1',
#  'CBRn1',
#  'CBTp1',
#  'CTNM1',
#  'CTTL1',
#  'CkSm1',
#  'CpEP1',
#  'DATA1',
#  'DATA2',
#  'DATA3',
#  'DATA4',
#  'DATA5',
#  'DATA6',
#  'DATA7',
#  'DATA8',
#  'DATA9',
#  'DATA10',
#  'DATA11',
#  'DATA12',
#  'DATA105',
#  'DATA106',
#  'DATA205',
#  'DATA206',
#  'DCMD1',
#  'DCMD2',
#  'DSam1',
#  'DySN1',
#  'Dye#1',
#  'DyeN1',
#  'DyeN2',
#  'DyeN3',
#  'DyeN4',
#  'DyeN5',
#  'DyeN6',
#  'DyeW1',
#  'DyeW2',
#  'DyeW3',
#  'DyeW4',
#  'DyeW5',
#  'DyeW6',
#  'EPVt1',
#  'EVNT1',
#  'EVNT2',
#  'EVNT3',
#  'EVNT4',
#  'GTyp1',
#  'HCFG1',
#  'HCFG2',
#  'HCFG3',
#  'HCFG4',
#  'InSc1',
#  'InVt1',
#  'InjN1',
#  'LANE1',
#  'LIMS1',
#  'LNTD1',
#  'LsrP1',
#  'MCHN1',
#  'MODF1',
#  'MODL1',
#  'NAVG1',
#  'NLNE1',
#  'NrmS3',
#  'OfSc1',
#  'OffS1',
#  'OvrI9',
#  'OvrI10',
#  'OvrI11',
#  'OvrI12',
#  'OvrI205',
#  'OvrI206',
#  'OvrV9',
#  'OvrV10',
#  'OvrV11',
#  'OvrV12',
#  'OvrV205',
#  'OvrV206',
#  'PANm1',
#  'PSZE1',
#  'PTYP1',
#  'PXLB1',
#  'Peak1',
#  'Peak2',
#  'Peak3',
#  'Peak4',
#  'Peak5',
#  'Peak6',
#  'Peak7',
#  'Peak8',
#  'Peak9',
#  'Peak10',
#  'Peak11',
#  'Peak12',
#  'Peak13',
#  'Peak14',
#  'Peak15',
#  'Peak16',
#  'Peak17',
#  'Peak18',
#  'Peak20',
#  'Peak21',
#  'Peak22',
#  'Peak24',
#  'Peak25',
#  'RGNm1',
#  'RMXV1',
#  'RMdN1',
#  'RMdV1',
#  'RMdX1',
#  'RNmF1',
#  'RPrN1',
#  'RPrV1',
#  'RUND1',
#  'RUND2',
#  'RUND3',
#  'RUND4',
#  'RUNT1',
#  'RUNT2',
#  'RUNT3',
#  'RUNT4',
#  'Rate1',
#  'RunN1',
#  'SCAN1',
#  'SMED1',
#  'SMID1',
#  'SMLt1',
#  'SMPL1',
#  'SMRn1',
#  'SMap1',
#  'SMap2',
#  'STYP1',
#  'SVER1',
#  'SVER2',
#  'SVER3',
#  'SVER4',
#  'SZTS1',
#  'SamQ1',
#  'Satd1',
#  'ScPa1',
#  'ScSt1',
#  'Scal1',
#  'Scan1',
#  'Sm#P1',
#  'SpNm1',
#  'SpeN1',
#  'StdF1',
#  'SzFt1',
#  'SzFt2',
#  'TUBE1',
#  'Tmpr1',
#  'User2']

# %%
non_empty_channels = {
    channel: raw_data[channel] 
    for channel in raw_data 
    if raw_data[channel] is not None
}
print("Non-empty channels:", non_empty_channels.keys())
# Out:
# Non-empty channels: dict_keys(['AAct1', 'ABED1', 'ABID1', 'ABLt1', 'ABRn1', 'ABTp1', 'APXV1', 'APrN1', 'APrV1', 'APrX1', 'AVld1', 'AmbT1', 'Anld1', 'AsyN1', 'AsyV1', 'CAED1', 'CAID1', 'CALt1', 'CARn1', 'CASN1', 'CBED1', 'CBID1', 'CBLt1', 'CBRn1', 'CBTp1', 'CTNM1', 'CTTL1', 'CkSm1', 'CpEP1', 'DCMD1', 'DCMD2', 'DSam1', 'Dye#1', 'DyeN6', 'DyeW1', 'DyeW2', 'DyeW3', 'DyeW4', 'DyeW5', 'DyeW6', 'EPVt1', 'EVNT1', 'EVNT2', 'EVNT3', 'EVNT4', 'GTyp1', 'HCFG1', 'HCFG4', 'InSc1', 'InVt1', 'InjN1', 'LANE1', 'LIMS1', 'LNTD1', 'LsrP1', 'MCHN1', 'MODF1', 'NAVG1', 'NLNE1', 'NrmS3', 'OvrI9', 'OvrI10', 'OvrI11', 'OvrI12', 'OvrI205', 'OvrI206', 'OvrV9', 'OvrV10', 'OvrV11', 'OvrV12', 'OvrV205', 'OvrV206', 'PSZE1', 'PTYP1', 'PXLB1', 'RGNm1', 'RMXV1', 'RMdN1', 'RMdV1', 'RMdX1', 'RNmF1', 'RPrN1', 'RPrV1', 'RUND1', 'RUND2', 'RUND3', 'RUND4', 'RUNT1', 'RUNT2', 'RUNT3', 'RUNT4', 'RunN1', 'SCAN1', 'SMED1', 'SMID1', 'SMLt1', 'SMPL1', 'SMRn1', 'STYP1', 'SVER1', 'SVER2', 'SVER3', 'SVER4', 'SZTS1', 'ScSt1', 'Scal1', 'Scan1', 'Sm#P1', 'SpNm1', 'SpeN1', 'StdF1', 'SzFt2', 'TUBE1', 'Tmpr1', 'User2'])

# %%
for channel in non_empty_channels:
    data = raw_data[channel]
    if isinstance(data, (list, tuple)) and len(data) > 10:  # Arbitrary threshold
        print(f"{channel}: Length={len(data)}")
# Out:
# AmbT1: Length=446

# %%
raw_data = record.annotations["abif_raw"]
raw_data
# Out:
# {'AAct1': False,
#  'ABED1': b'2017-12-02 23:59:00.0',
#  'ABID1': b'2017-05-23 09:27:00.0',
#  'ABLt1': b'1702373',
#  'ABRn1': 3,
#  'ABTp1': b'ABC',
#  'APXV1': b'1',
#  'APrN1': b'WEN ILS 500',
#  'APrV1': b'SizeCaller v1.1.0',
#  'APrX1': b'<?xml version="1.0" encoding="UTF-8"?> <qc-protocol name="WEN ILS 500" version="SizeCaller v1.1.0" userName="" comments="" created="1448924566419" createUserName="" modified="1448924566409" modifyUserName="" uuid="71ca151e-5199-475c-a0dc-8e2c7507e207" securityID="" immutable="false" systemOwned="false" locked="false" unlockable="true" validated="false" checksum="0xD49034D8F19CECC411FEE9580240B25F" rgb="0;0;0" auditActive="0" iconFile=""><qcParameter><analysisSettings><parameterMap><parameter name="AnalysisDyes">1,2,3,4,5,6</parameter><parameter name="AnalysisMode">1</parameter><parameter name="AnalysisStopPoint">1000000</parameter><parameter name="PeakDetectorTauB">key=1,value=0.0;key=2,value=0.0;key=3,value=0.0;key=4,value=0.0;key=5,value=0.0;key=6,value=0.0;</parameter><parameter name="PeakDetectorDegree">key=1,value=3;key=2,value=3;key=3,value=3;key=4,value=3;key=5,value=3;key=6,value=3;</parameter><parameter name="AnalysisAllDyes">true</parameter><parameter name="BaseliningWindowSize">key=1,value=51;key=2,value=51;key=3,value=51;key=4,value=51;key=5,value=51;key=6,value=51;</parameter><parameter name="SizingQualityCheckingRangeStart">0.0</parameter><parameter name="AnalysisFullRange">true</parameter><parameter name="PeakDetectorMinWidth">key=1,value=2;key=2,value=2;key=3,value=2;key=4,value=2;key=5,value=2;key=6,value=2;</parameter><parameter name="PrimerPeakPresent">true</parameter><parameter name="SizingFullRange">false</parameter><parameter name="SizingStopSize">500.0</parameter><parameter name="SmoothingValue">key=1,value=2;key=2,value=2;key=3,value=2;key=4,value=2;key=5,value=2;key=6,value=2;</parameter><parameter name="SizingQualityCheckingRangeStop">800.0</parameter><parameter name="SizingStartSize">60.0</parameter><parameter name="SmoothingNeeded">key=1,value=true;key=2,value=true;key=3,value=true;key=4,value=true;key=5,value=true;key=6,value=true;</parameter><parameter name="PeakDetectorWindow">key=1,value=15;key=2,value=15;key=3,value=15;key=4,value=15;key=5,value=15;key=6,value=15;</parameter><parameter name="AnalysisStartPoint">0</parameter><parameter name="PeakDetectorTauE">key=1,value=0.0;key=2,value=0.0;key=3,value=0.0;key=4,value=0.0;key=5,value=0.0;key=6,value=0.0;</parameter><parameter name="BaseliningNeeded">key=1,value=true;key=2,value=true;key=3,value=true;key=4,value=true;key=5,value=true;key=6,value=true;</parameter><parameter name="SizingQualityCheckingNeeded">true</parameter><parameter name="SizeCallerName">LocalSouthern</parameter><parameter name="PeakDetectorMinHeight">key=1,value=175;key=2,value=175;key=3,value=175;key=4,value=175;key=5,value=175;key=6,value=175;</parameter></parameterMap></analysisSettings><size-standard parserID="com.apldbio.ce.pa.fragment.da.SizeStandardDAO"><sizeStandard name="WEN ILS 500" version="v1.0.0" userName="" comments="" created="1448924489679" createUserName="" modified="1448924489679" modifyUserName="" uuid="e69975b7-b2fb-4f3d-b686-75461436bd46" securityID="" immutable="false" systemOwned="false" locked="false" unlockable="true" validated="false" checksum="0x3F07A216B6EB7989058E736EBAF84FFC" rgb="0;0;0" auditActive="0" iconFile=""><dyeIndex>5</dyeIndex><sizes>60.0,65.0,80.0,100.0,120.0,140.0,160.0,180.0,200.0,225.0,250.0,275.0,300.0,325.0,350.0,375.0,400.0,425.0,450.0,475.0,500.0</sizes><normalization></normalization></sizeStandard></size-standard></qcParameter><qcFlagSetting><flagSettings><settingMap><setting name="SizingQualityThresholds">0.75,0.25</setting><setting name="SpectralPullupScan">1</setting><setting name="BroadPeakAffectingSizingQualityWeight">0.5</setting><setting name="SpectralPullupRatio">0.1</setting><setting name="BroadPeakThreshold">1.5</setting></settingMap></flagSettings></qcFlagSetting></qc-protocol>',
#  'AVld1': b'false',
#  'AmbT1': (23,
#   23,
#   23,
#   23,
#   23,
#   23,
#   23,
#   23,
#   23,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24,
#   24),
#  'Anld1': True,
#  'AsyC1': None,
#  'AsyN1': b'PPF6C_13 kV run_15s inj',
#  'AsyV1': b'v1.0.0',
#  'CAED1': b'2015-01-21 23:59:00.0',
#  'CAID1': b'2016-12-01 14:10:00.0',
#  'CALt1': b'24',
#  'CARn1': 153,
#  'CASN1': b'M314B2403',
#  'CBED1': b'2017-07-09 23:59:00.0',
#  'CBID1': b'2017-05-23 09:28:00.0',
#  'CBLt1': b'1610389',
#  'CBRn1': 3,
#  'CBTp1': b'CBC',
#  'CTNM1': b'053017_PPF6C_SRM2391d_bloodscreen',
#  'CTTL1': b'Comment:',
#  'CkSm1': b'W5IFK47FNygHlOqfP87EbQ==',
#  'CpEP1': b'\x01',
#  'DATA1': None,
#  'DATA2': None,
#  'DATA3': None,
#  'DATA4': None,
#  'DATA5': None,
#  'DATA6': None,
#  'DATA7': None,
#  'DATA8': None,
#  'DATA9': None,
#  'DATA10': None,
#  'DATA11': None,
#  'DATA12': None,
#  'DATA105': None,
#  'DATA106': None,
#  'DATA205': None,
#  'DATA206': None,
#  'DCMD1': b'RUO',
#  'DCMD2': b'RUO',
#  'DSam1': 1,
#  'DySN1': None,
#  'Dye#1': 6,
#  'DyeN1': None,
#  'DyeN2': None,
#  'DyeN3': None,
#  'DyeN4': None,
#  'DyeN5': None,
#  'DyeN6': b' LIZ',
#  'DyeW1': 522,
#  'DyeW2': 554,
#  'DyeW3': 575,
#  'DyeW4': 595,
#  'DyeW5': 620,
#  'DyeW6': 655,
#  'EPVt1': 13000,
#  'EVNT1': b'Run Started',
#  'EVNT2': b'Run Stopped',
#  'EVNT3': b'Collection Started',
#  'EVNT4': b'Collection Stopped',
#  'GTyp1': b'POP4',
#  'HCFG1': b'CE',
#  'HCFG2': None,
#  'HCFG3': None,
#  'HCFG4': b'UnitID=10;CPUBoard=UCPU-110;ArraySize=24;SerialNumber=24343-080;',
#  'InSc1': 15,
#  'InVt1': 1200,
#  'InjN1': b'Injection 2017-05-30-09-26-18-775',
#  'LANE1': 19,
#  'LIMS1': b'89609cf1-93e8-40fe-8553-28d10133f188',
#  'LNTD1': 36,
#  'LsrP1': 20000,
#  'MCHN1': b'3500 Instrument',
#  'MODF1': b'HID36_POP4xl',
#  'MODL1': None,
#  'NAVG1': 1,
#  'NLNE1': 24,
#  'NrmS3': False,
#  'OfSc1': None,
#  'OffS1': None,
#  'OvrI9': (),
#  'OvrI10': (),
#  'OvrI11': (),
#  'OvrI12': (),
#  'OvrI205': (),
#  'OvrI206': (),
#  'OvrV9': (),
#  'OvrV10': (),
#  'OvrV11': (),
#  'OvrV12': (),
#  'OvrV205': (),
#  'OvrV206': (),
#  'PANm1': None,
#  'PSZE1': 96,
#  'PTYP1': b'96-Well',
#  'PXLB1': 3,
#  'Peak1': None,
#  'Peak2': None,
#  'Peak3': None,
#  'Peak4': None,
#  'Peak5': None,
#  'Peak6': None,
#  'Peak7': None,
#  'Peak8': None,
#  'Peak9': None,
#  'Peak10': None,
#  'Peak11': None,
#  'Peak12': None,
#  'Peak13': None,
#  'Peak14': None,
#  'Peak15': None,
#  'Peak16': None,
#  'Peak17': None,
#  'Peak18': None,
#  'Peak20': None,
#  'Peak21': None,
#  'Peak22': None,
#  'Peak24': None,
#  'Peak25': None,
#  'RGNm1': b'IdentifilerPPF6C_13kV run_15s inj',
#  'RMXV1': b'v1.0.0',
#  'RMdN1': b'HID36_POP4xl',
#  'RMdV1': b'v1.0.0',
#  'RMdX1': b'//\n//\nSYSTem:MESSage "$DC_RunModule_Comment"\n//\n//\n//\n//\tTurning Laser On\n//\nSYSTem:MESSage "Turning Laser On."\nLAS:POW:SETT $DC_Laser_Power_Setting\nLAS:POW:TOL 1.0\nLAS On\n//\n//\n//\tTurning Zohana On\n//\nSYSTem:MESSage "Turning Detection Heater On."\nDETH:TEMP:TOL 3.0\nDETH:TEMP:SETT $Array_Heater_Temperature\nDETH On\n//\n//\n//\tTurning Oven On\n//\nSYSTem:MESSage "Setting Oven Temperature."\nOVEN:TEMP:TOL $Temperature_Tolerance\nOVEN:TEMP:SETT $Oven_Temperature\nOVEN On\n//\n//\n//\tInitializing Autosampler\n//\nSYSTem:MESSage "Initializing Autosampler."\nSTR Initialize\n//\n//\tFilling Polymer Pump\n//\nSYSTem:MESSage "Loading Waste Tray."\nSTR:ROB:MOV:LOAD Waste\nFLU:POLY:PRES Up 0.34 50\nFLU:POLY:PRES Down 0.21 200\nSYSTem:MESSage "Filling Polymer Pump"\nFLU:POLY:FILL $Poly_Fill_Vol\n//\n//\tWaiting for Oven to Stabilize at Run Temperature\n//\nSYSTem:MESSage "Waiting for Oven to Stabilize at Run Temperature"\nOVEN:SYNC $Oven_Wait_Time\n//\n//\tWaiting for Detection Heater to Stabilize at Run Temperature\n//\nSYSTem:MESSage "Waiting for Detection Heater to Stabilize at Run Temperature"\nDETH:SYNC 1800\n//\n//\tWaiting for Laser to Stabilize at Power Setting\n//\nSYSTem:MESSage "Waiting for Laser to Stabilize at Power Setting"\nLAS:SYNC 600\n//\n//\n//\tFilling Array\n//\nSYSTem:MESSage "Filling Array with Polymer."\nFLU:CAP:FILL:THRE 150\nFLU:CAP:FILL $Cap_Fill_Vol\n//\n//\tRinsing Capillaries\n//\nSYSTem:MESSage "Rinsing Capillary Tips."\nSTR:ROB:MOV:LOAD Water\nSYST:WAIT 3\n//\nSYSTem:MESSage "Loading Buffer Tray."\nSTR:ROB:MOV:LOAD Buffer\nSYST:WAIT 3\n//\n//\tBubble Check\n//\nSYSTem:MESSage "Testing for Normal Current."\nEPS:CURR:LIM $Max_Current\nEPS:CURR:ARC:THRE $Current_Stability\nEPS:VOLT:SETT 1.0\nEPS On\nSYST:WAIT 2\nEPS:CURR:ARC:SELF $DC_Cap24_EPS_ARC_SELF\nEPS Off\n//\n//\tPre Run\n//\nSYSTem:MESSage "PreRun"\nEPS:VOLT:TOL $Voltage_Tolerance\nEPS:VOLT:SETT $PreRun_Voltage\nEPS On\nEPS:SYNC 10\nSYST:WAIT $DC_PreRun_Time\nEPS Off\nSYST:WAIT 3\n//\n//\n//\tRinse Capillaries\n//\nSYSTem:MESSage "Rinsing Capillary Tips."\nSTR:ROB:MOV:LOAD Water\nSYST:WAIT 3\n//\n// Sample injection\n//\nSYSTem:MESSage "Sample Injection."\nSTR:ROB:ZOFF $Injection_Depth_Offset\nSTR:CSO $DC_RS_CSData\nSTR:ROB:MOV:LOAD $DC_RS_Plate_Type\nSYST:WAIT 15\nEPS:VOLT:SETT $Injection_Voltage\nEPS On\nSYST:WAIT $DC_Injection_Time\nEPS Off\nEPS:VOLT:SETT 0.0\nSYST:WAIT 1\nSTR:ROB:ZOFF 0\n//\n//\tRinsing Capillaries\n//\nSYSTem:MESSage "Rinsing Capillary Tips."\nSTR:ROB:MOV:LOAD Water\nSYST:WAIT 3\n//\n//\tStarting Electrophoresis\n//\nSYSTem:MESSage "Loading Buffer Tray."\nSTR:ROB:MOV:LOAD Buffer\nSYST:WAIT 3\nSYSTem:MESSage "Ramping Cycle."\nEPS:VOLT:TOL $Voltage_Tolerance\nEPS:VOLT:SQRR $Run_Voltage $Voltage_Number_Of_Steps $Voltage_Step_Interval\nEPS On\nSYST:WAIT $Voltage_Ramp_Wait\nEPS:SYNC 10\n//\n//\tData Delay\n//\nSYSTem:MESSage "Waiting for Data."\nSYST:WAIT $DC_Data_Delay\n//\n//\tCCD beginning data read\n//\nCAM:SHUT Auto\nDAT:SRAT $First_ReadOut_Time $Second_ReadOut_Time\nDAT:MODe Binning\nSYSTem:MESSage "Starting Data Collection."\nDAT:COLL Start\nSYST:WAIT $DC_Run_Time\nSYSTem:MESSage "Stop Data Collection."\nDAT:COLL Stop\nEPS Off\nEPS:VOLT:SETT 0.0\nSYST:WAIT 1\n//LAS Off\n//DETH Off\n//OVEN Off\n//\n//\n//\tEnd Of Module',
#  'RNmF1': 1.0,
#  'RPrN1': b'PPF6C_13kV run_15s inj',
#  'RPrV1': b'v1.0.0',
#  'RUND1': '2017-05-30',
#  'RUND2': '2017-05-30',
#  'RUND3': '2017-05-30',
#  'RUND4': '2017-05-30',
#  'RUNT1': '09:27:19',
#  'RUNT2': '10:04:39',
#  'RUNT3': '09:38:43',
#  'RUNT4': '10:04:34',
#  'Rate1': None,
#  'RunN1': b'Run 2017-05-30-09-25-54-355',
#  'SCAN1': 9644,
#  'SMED1': b'2017-06-18 23:59:00.0',
#  'SMID1': b'2017-04-03 08:14:00.0',
#  'SMLt1': b'1610113',
#  'SMPL1': b'Sample',
#  'SMRn1': 21,
#  'SMap1': None,
#  'SMap2': None,
#  'STYP1': b'Sample',
#  'SVER1': b'3500 Series Data Collection Software 3 v3.0 (2,135)',
#  'SVER2': b'SizeCaller v1.1.0',
#  'SVER3': b'6228001-05',
#  'SVER4': b'Fragment Format 2.0',
#  'SZTS1': b'2017-05-30 10:05:23.986',
#  'SamQ1': None,
#  'Satd1': None,
#  'ScPa1': None,
#  'ScSt1': 0,
#  'Scal1': 2.0,
#  'Scan1': 9644,
#  'Sm#P1': 21,
#  'SpNm1': b'7',
#  'SpeN1': b'Run 2016-12-05-11-21-18-897',
#  'StdF1': b'WEN ILS 500',
#  'SzFt1': None,
#  'SzFt2': 0.999995792013317,
#  'TUBE1': b'G07',
#  'Tmpr1': 60,
#  'User2': b''}
